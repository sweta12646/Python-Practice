# %% [markdown]
# # 🐍 Python Practice Question Bank
# ### Beginner Level | Variables · Data Types · Operators · Strings · Indexing · Slicing
# ---
# > **Instructions:**
# > - 🖊️ **Code Writing** — Write Python code in the empty cell below each question.
# > - 🔍 **Predict the Output** — Read the code carefully, write your expected output as comments, then run.
# > - Do **not** use built-in methods unless the question allows it.
# > - All questions are compatible with **Python 3**.

# %% [markdown]
# ---
# ---
# ## 📘 Section 1: Variables & Data Types
# ### *(20 Questions — 16 Code Writing | 4 Predict Output)*

# %% [markdown]
# ---
#
# **Q1. 🖊️ Code Writing**
#
# Create four variables:
# - `name` storing your name as a string
# - `age` storing your age as an integer
# - `height` storing your height in cm as a float
# - `is_employed` storing `False` as a boolean
#
# Print all four variables on separate lines.

# %%
name = "swetalina"
age = 22
height = 160.5
is_employed = False

print(name)
print(age)
print(height)
print(is_employed)
# Out:
# Anjolina
# 22
# 160.5
# False

# %% [markdown]
# ---
#
# **Q2. 🖊️ Code Writing**
#
# Create a variable `city = "Bhubaneswar"`.
# - Print the variable
# - Print its data type using `type()`

# %%
city = "Bhubaneswar"

print(city)
print(type(city))
# Out:
# Bhubaneswar
# <class 'str'>

# %% [markdown]
# ---
#
# **Q3. 🖊️ Code Writing**
#
# Store the value `3 + 4j` in a variable `z`. Print:
# - The variable `z`
# - Its data type
# - Its real part
# - Its imaginary part

# %%
z = 3 + 4j

print(z)
print(type(z))
print(z.real)
print(z.imag)
# Out:
# (3+4j)
# <class 'complex'>
# 3.0
# 4.0

# %% [markdown]
# ---
#
# **Q4. 🖊️ Code Writing**
#
# Assign the same value `100` to three variables `x`, `y`, and `z` using a **single line** of code.
# Print all three.

# %%
x = y = z = 100

print(x)
print(y)
print(z)
# Out:
# 100
# 100
# 100

# %% [markdown]
# ---
#
# **Q5. 🖊️ Code Writing**
#
# Create two variables `a = 50` and `b = 75`.
# Swap their values **without using a third variable**.
# Print `a` and `b` after swapping.

# %%
a = 50
b = 75

a, b = b, a

print(a,b)
# Out:
# 75 50

# %% [markdown]
# ---
#
# **Q6. 🖊️ Code Writing**
#
# Create variables of all five data types: `int`, `float`, `str`, `bool`, and `complex`.
# Print each variable along with its type in this format:
# ```
# Value: 10  |  Type: <class 'int'>
# ```

# %%
a = 10
b = 10.5
c = "Python"
d = True
e = 2 + 3j

print("Value:", a, "| Type:", type(a))
print("Value:", b, "| Type:", type(b))
print("Value:", c, "| Type:", type(c))
print("Value:", d, "| Type:", type(d))
print("Value:", e, "| Type:", type(e))
# Out:
# Value: 10 | Type: <class 'int'>
# Value: 10.5 | Type: <class 'float'>
# Value: Python | Type: <class 'str'>
# Value: True | Type: <class 'bool'>
# Value: (2+3j) | Type: <class 'complex'>

# %% [markdown]
# ---
#
# **Q7. 🖊️ Code Writing**
#
# Demonstrate **type conversion**:
# - Convert the integer `42` to a float and print it
# - Convert the float `9.99` to an integer and print it
# - Convert the integer `100` to a string and print it with its type

# %%
num = 42
print(float(num))

value = 9.99
print(int(value))

x = 100
s = str(x)
print(s)
print(type(s))
# Out:
# 42.0
# 9
# 100
# <class 'str'>

# %% [markdown]
# ---
#
# **Q8. 🖊️ Code Writing**
#
# Create two variables: `p = "25"` and `q = "30"`.
# - First print `p + q` (string concatenation)
# - Then convert both to integers and print their sum
#
# Observe the difference.

# %%
p = "25"
q = "30"

print(p + q)

print(int(p) + int(q))
# Out:
# 2530
# 55

# %% [markdown]
# ---
#
# **Q9. 🖊️ Code Writing**
#
# Create a variable `flag = True`.
# - Print `flag`
# - Print `flag + 1`
# - Print `flag * 10`
# - Print the type of `flag`

# %%
flag = True

print(flag)
print(flag + 1)
print(flag * 10)
print(type(flag))
# Out:
# True
# 2
# 10
# <class 'bool'>

# %% [markdown]
# ---
#
# **Q10. 🖊️ Code Writing**
#
# Write code to create a student profile using five variables:
# `roll_no`, `student_name`, `percentage`, `passed`, `grade`
#
# Assign appropriate values and data types to each.
# Print all five on separate lines.

# %%
roll_no = 101
student_name = "Amit"
percentage = 89.5
passed = True
grade = "A"

print((roll_no)
print(student_name)
print(percentage)
print(passed)
print(grade)
# Out:
# <class 'int'>
# Amit
# 89.5
# True
# A

# %% [markdown]
# ---
#
# **Q11. 🔍 Predict the Output**
#
# ```python
# x = 10
# y = 3.0
# z = x + y
# print(z)
# print(type(z))
# ```

# %%
x = 10
y = 3.0
z = x + y
print(z)
print(type(z))
# Out:
# 13.0
# <class 'float'>

# %% [markdown]
# ---
#
# **Q12. 🖊️ Code Writing**
#
# Create two variables `first_name = "Amit"` and `last_name = "Sharma"`.
# Join them with a space and store in `full_name`.
# Print `full_name`.

# %%
first_name = "Amit"
last_name = "Sharma"

full_name = first_name + " " + last_name

print(full_name)
# Out:
# Amit Sharma

# %% [markdown]
# ---
#
# **Q13. 🖊️ Code Writing**
#
# A product has the following details:
# - Product name: `"Laptop"`
# - Price: `55999.99`
# - In Stock: `True`
# - Units Available: `15`
#
# Store each in an appropriately named variable and print all details.

# %%
product_name = "Laptop"
price = 55999.99
in_stock = True
units_available = 15

print(product_name)
print(price)
print(in_stock)
print(units_available)
# Out:
# Laptop
# 55999.99
# True
# 15

# %% [markdown]
# ---
#
# **Q14. 🔍 Predict the Output**
#
# ```python
# a = True
# b = False
# print(a + b)
# print(a * 5)
# print(b + 10)
# ```

# %%
a = True
b = False

print(a + b)
print(a * 5)
print(b + 10)
# Out:
# 1
# 5
# 10

# %% [markdown]
# ---
#
# **Q15. 🖊️ Code Writing**
#
# Create a variable `score = 95.5`.
# - Print the type of `score`
# - Convert it to `int` and print the result
# - Convert it to `str` and print the type of the result

# %%
score = 95.5

print(type(score))

score_int = int(score)
print(score_int)

score_str = str(score)
print(type(score_str))
# Out:
# <class 'float'>
# 95
# <class 'str'>

# %% [markdown]
# ---
#
# **Q16. 🖊️ Code Writing**
#
# Show Python is **dynamically typed**:
# - Assign `x = 10` (integer) and print its type
# - Reassign `x = "Python"` (string) and print its type
# - Reassign `x = 3.14` (float) and print its type

# %%
x = 10
print(type(x))

x = "Python"
print(type(x))

x = 3.14
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# ---
#
# **Q17. 🖊️ Code Writing**
#
# Create three variables in a single line:
# ```
# a = 5, b = 10, c = 15
# ```
# using Python's multiple assignment feature. Print all three.

# %%
a, b, c = 5, 10, 15

print(a,b,c)
# Out:
# 5 10 15

# %% [markdown]
# ---
#
# **Q18. 🔍 Predict the Output**
#
# ```python
# x = "5"
# y = 5
# print(x == y)
# print(type(x) == type(y))
# print(int(x) == y)
# ```

# %%
x = "5"
y = 5
print(x == y)
print(type(x) == type(y))
print(int(x) == y)
# Out:
# False
# False
# True

# %% [markdown]
# ---
#
# **Q19. 🖊️ Code Writing**
#
# An employee record has:
# - `emp_id = 1042` (int)
# - `emp_name = "Rekha Nair"` (str)
# - `salary = 48500.75` (float)
# - `is_active = True` (bool)
#
# Print each field with a label, like:
# ```
# Employee ID: 1042
# Name: Rekha Nair
# ```

# %%
emp_id = 1042
emp_name = "Anjolina sahoo"
salary = 48500.75
is_active = True

print("Employee ID:", emp_id)
print("Name:", emp_name)
print("Salary:", salary)
print("Active:", is_active)
# Out:
# Employee ID: 1042
# Name: Anjolina sahoo
# Salary: 48500.75
# Active: True

# %% [markdown]
# ---
#
# **Q20. 🔍 Predict the Output**
#
# ```python
# x = 100
# y = x
# x = 200
# print(x)
# print(y)
# ```

# %%
x = 100
y = x
x = 200

print(x)
print(y)
# Out:
# 200
# 100

# %% [markdown]
# ---
# ---
# ## 📗 Section 2: Arithmetic Operators
# ### *(20 Questions — 16 Code Writing | 4 Predict Output)*

# %% [markdown]
# ---
#
# **Q21. 🖊️ Code Writing**
#
# Store `a = 27` and `b = 4`.
# Print the result of all arithmetic operations: `+`, `-`, `*`, `/`, `//`, `%`, `**`.
# Add a comment next to each line explaining what it does.

# %%
# Store the values
a = 27
b = 4

print(a + b)   # Adds a and b
print(a - b)   # Subtracts b from a
print(a * b)   # Multiplies a and b
print(a / b)   # Divides a by b (returns float)
print(a // b)  # Floor division (quotient without decimal)
print(a % b)   # Modulus (remainder after division)
print(a ** b)  # Raises a to the power of b
# Out:
# 31
# 23
# 108
# 6.75
# 6
# 3
# 531441

# %% [markdown]
# ---
#
# **Q22. 🖊️ Code Writing**
#
# A rectangle has `length = 12` and `breadth = 7`. Calculate and print:
# - **Perimeter** = `2 * (length + breadth)`
# - **Area** = `length * breadth`

# %%
length = 12
breadth = 7
perimeter = 2 * (length + breadth)
area = length * breadth
print("Perimeter:", perimeter)
print("Area:", area)
# Out:
# Perimeter: 38
# Area: 84

# %% [markdown]
# ---
#
# **Q23. 🖊️ Code Writing**
#
# A student scored marks in 5 subjects: `85, 90, 78, 92, 88`.
# Store them in 5 separate variables.
# Calculate and print the **total** and **average**.

# %%
mark1 = 85
mark2 = 90
mark3 = 78
mark4 = 92
mark5 = 88
total = mark1 + mark2 + mark3 + mark4 + mark5
average = total / 5
print("Total Marks:", total)
print("Average Marks:", average)

# %% [markdown]
# ---
#
# **Q24. 🖊️ Code Writing**
#
# Write code to check if the number `128` is **even or odd** using the modulus operator.
# Store the result of `128 % 2` in a variable and print it.
# Add a comment explaining what the result means.

# %%
result = 128 % 2

print(result)
# Out:
# 0

# %% [markdown]
# ---
#
# **Q25. 🖊️ Code Writing**
#
# A box contains `250` chocolates to be divided equally among `12` children.
# Using floor division and modulus:
# - Print how many chocolates **each child gets**
# - Print how many chocolates are **left over**

# %%
chocolates = 250
children = 12
each_child = chocolates // children
left_over = chocolates % children
print("Each child gets:", each_child)
print("Chocolates left over:", left_over)
# Out:
# Each child gets: 20
# Chocolates left over: 10

# %% [markdown]
# ---
#
# **Q26. 🖊️ Code Writing**
#
# Calculate the following using Python:
# - 2 raised to the power 8
# - Square root of 144 (using `** 0.5`)
# - Cube of 7
#
# Print all three results.

# %%
power = 2 ** 8
square_root = 144 ** 0.5
cube = 7 ** 3
print("2^8 =", power)
print("Square root of 144 =", square_root)
print("Cube of 7 =", cube)
# Out:
# 2^8 = 256
# Square root of 144 = 12.0
# Cube of 7 = 343

# %% [markdown]
# ---
#
# **Q27. 🖊️ Code Writing**
#
# Temperature conversion:
# Given `celsius = 37`, convert it to Fahrenheit.
# Formula: `F = (C * 9/5) + 32`
# Print the result.

# %%
celsius = 37

fahrenheit = (celsius * 9/5) + 32
print("Temperature in Fahrenheit:", fahrenheit)

# %% [markdown]
# ---
#
# **Q28. 🔍 Predict the Output**
#
# ```python
# x = 17
# y = 5
# print(x / y)
# print(x // y)
# print(x % y)
# print(x ** 2)
# ```

# %%
x = 17
y = 5

print(x / y)
print(x // y)
print(x % y)
print(x ** 2)
# Out:
# 3.4
# 3
# 2
# 289

# %% [markdown]
# ---
#
# **Q29. 🖊️ Code Writing**
#
# A shop sells pens at ₹8 each. A customer buys `37` pens.
# - Calculate the **total cost**
# - The customer pays ₹300 — calculate the **change** to be returned

# %%
price = 8
pens = 37
total_cost = price * pens
paid = 300
change = paid - total_cost
print("Total Cost:", total_cost)
print("Change Returned:", change)

# %% [markdown]
# ---
#
# **Q30. 🖊️ Code Writing**
#
# Verify the **Pythagorean theorem** for `a = 3`, `b = 4`, `c = 5`.
# Calculate `a**2 + b**2` and `c**2` and print both.
# Are they equal?

# %%
a = 3
b = 4
c = 5
left_side = a ** 2 + b ** 2
right_side = c ** 2
print("a² + b² =", left_side)
print("c² =", right_side)
print(left_side == right_side)
# Out:
# a² + b² = 25
# c² = 25
# True

# %% [markdown]
# ---
#
# **Q31. 🖊️ Code Writing**
#
# A train travels at `speed = 90` km/h for `distance = 450` km.
# Calculate and print the **time** required.
# Formula: `time = distance / speed`

# %%
# Store speed and distance
speed = 90
distance = 450

# Calculate time
time = distance / speed

# Print the result
print("Time Required:", time, "hours")
# Out:
# Time Required: 5.0 hours

# %% [markdown]
# ---
#
# **Q32. 🖊️ Code Writing**
#
# Given `n = 365`:
# - Find the number of **complete weeks** (using `//`)
# - Find the number of **remaining days** (using `%`)

# %%
n = 365
weeks = n // 7
days = n % 7
print("Complete weeks:", weeks)
print("Remaining days:", days)
# Out:
# Complete weeks: 52
# Remaining days: 1

# %% [markdown]
# ---
#
# **Q33. 🔍 Predict the Output**
#
# ```python
# print(10 // 3)
# print(-10 // 3)
# print(10 // -3)
# print(-10 // -3)
# ```

# %%
print(10 // 3)
print(-10 // 3)
print(10 // -3)
print(-10 // -3)
# Out:
# 3
# -4
# -4
# 3

# %% [markdown]
# ---
#
# **Q34. 🖊️ Code Writing**
#
# Simple Interest Calculation:
# - `principal = 5000`, `rate = 8`, `time = 3`
#
# Formula: `SI = (principal * rate * time) / 100`
#
# Calculate and print both the **Simple Interest** and the **Total Amount** (principal + SI).

# %%
principal = 5000
rate = 8
time = 3
si = (principal * rate * time) / 100
total_amount = principal + si
print("Simple Interest:", si)
print("Total Amount:", total_amount)
# Out:
# Simple Interest: 1200.0
# Total Amount: 6200.0

# %% [markdown]
# ---
#
# **Q35. 🖊️ Code Writing**
#
# Find the **last digit** of the number `9876` using the modulus operator.
# Find the **second-last digit** of the same number.
# Print both.

# %%
x=9876
last_digit =x%10
y=x//10
second_last_digit = y%10
print(last_digit)
print(second_last_digit)
# Out:
# 6
# 7

# %% [markdown]
# ---
#
# **Q36. 🖊️ Code Writing**
#
# A parking lot charges ₹20 for the first hour and ₹10 for every additional hour.
# `total_hours = 5`
#
# Calculate and print the total parking fee.

# %%
total_hours =5
fees=20+(total_hours-1)*10
print("total parking fees:",fees)
# Out:
# total parking fees: 60

# %% [markdown]
# ---
#
# **Q37. 🔍 Predict the Output**
#
# ```python
# a = 2
# b = 3
# c = 4
# print(a + b * c)
# print((a + b) * c)
# print(a ** b ** 2)
# print((a ** b) ** 2)
# ```

# %%
a = 2
b = 3
c = 4
print(a + b * c)
print((a + b) * c)
print(a ** b ** 2)
print((a ** b) ** 2)
# Out:
# 14
# 20
# 512
# 64

# %% [markdown]
# ---
#
# **Q38. 🖊️ Code Writing**
#
# Calculate the **digit sum** of the 4-digit number `1234`:
# - Extract each digit using `//` and `%`
# - Add them and print the digit sum
#
# *(Hint: units = n%10, tens = n//10%10, hundreds = n//100%10, thousands = n//1000)*

# %%
n=1234
units =n%10
tens =(n//10)%10
hundreds = (n//100)%10
thousands = n//1000
sum = units + tens + hundreds + thousands
print(sum)
# Out:
# 10

# %% [markdown]
# ---
#
# **Q39. 🖊️ Code Writing**
#
# A class has `total_students = 47` split into groups of `5`.
# - Print the number of **complete groups**
# - Print the number of **students left** without a complete group

# %%
total_students = 47
complete_groups = total_students // 5
remaining_students = total_students% 5
print("complete group:",complete_groups)
print("remaining student:",remaining_students)
# Out:
# complete group: 9
# remaining student: 2

# %% [markdown]
# ---
#
# **Q40. 🔍 Predict the Output**
#
# ```python
# a = 3
# b = 4
# c = 5
# print(a ** 2 + b ** 2 == c ** 2)
# print(2 + 3 * 4 - 1)
# print(10 % 3 + 7 // 2)
# ```

# %%
a = 3
b = 4
c = 5
print(a ** 2 + b ** 2 == c ** 2)
print(2 + 3 * 4 - 1)
print(10 % 3 + 7 // 2)
# Out:
# True
# 13
# 4

# %% [markdown]
# ---
# ---
# ## 📙 Section 3: Comparison & Logical Operators
# ### *(15 Questions — 12 Code Writing | 3 Predict Output)*

# %% [markdown]
# ---
#
# **Q41. 🖊️ Code Writing**
#
# Store `a = 45` and `b = 78`.
# Write code to check and print the result of all **6 comparison operators**: `>`, `<`, `==`, `!=`, `>=`, `<=`.
# Label each result clearly.

# %%
m = 45
n = 78
print(m>n)
print(m<n)
print(m==n)
print(m!=n)
print(m>=n)
print(m<=n)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ---
#
# **Q42. 🖊️ Code Writing**
#
# A student needs **at least 40 marks** to pass. `marks = 38`
#
# Use a comparison operator to check if the student passed.
# Store the result in `passed` and print it.

# %%
marks = 38
passed_mark = marks>=40
print(passed_mark)
# Out:
# False

# %% [markdown]
# ---
#
# **Q43. 🖊️ Code Writing**
#
# Check if `n = 55` lies **between 50 and 100** (inclusive).
# Use a single expression with the `and` operator and print the result.

# %%
n = 55
result = 50<=n<=100
print(result)
# Out:
# True

# %% [markdown]
# ---
#
# **Q44. 🖊️ Code Writing**
#
# A movie ticket gives discount if age is **below 12 OR above 60**. `age = 65`
#
# Write code to check eligibility. Store the result in `is_eligible` and print it.

# %%
age = 65
is_eligible = age < 12 or age > 60
print(is_eligible)
# Out:
# True

# %% [markdown]
# ---
#
# **Q45. 🖊️ Code Writing**
#
# A login system checks: `username == "admin"` AND `password == "secure123"`
#
# Set the variables and write code to check if login is successful. Print the result.

# %%
username = "admin"
password = "secure123"
login_successful = username == "admin" and password == "secure123"
print(login_successful)
# Out:
# True

# %% [markdown]
# ---
#
# **Q46. 🖊️ Code Writing**
#
# `year = 2024`
#
# Use the modulus and comparison operator to check if it is divisible by 4.
# Print the boolean result.

# %%
year = 2024
is_leap_year = year % 4 == 0 
print(is_leap_year)
# Out:
# True

# %% [markdown]
# ---
#
# **Q47. 🔍 Predict the Output**
#
# ```python
# x = 10
# y = 20
# z = 10
# print(x == z)
# print(x != y)
# print(x > y or x == z)
# print(x < y and y > z)
# print(not (x == y))
# ```

# %%
x = 10
y = 20
z = 10
print(x == z)
print(x != y)
print(x > y or x == z)
print(x < y and y > z)
print(not (x == y))
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# ---
#
# **Q48. 🖊️ Code Writing**
#
# An airline allows baggage if weight ≤ 20 kg OR the passenger has premium membership.
# `weight = 25`, `is_premium = True`
#
# Write code and print whether baggage is allowed.

# %%
weight = 25
is_premium = True
baggage_allowed = weight <=20 or is_premium
print(baggage_allowed)
# Out:
# True

# %% [markdown]
# ---
#
# **Q49. 🖊️ Code Writing**
#
# A bank account requires balance > 1000 AND `is_active = True`.
# `balance = 850`, `is_active = True`
#
# Check if the account meets both conditions. Print the result.

# %%
is_active = True
balance = 850
account_valid = balance > 1000 and is_active
print(account_valid)
# Out:
# False

# %% [markdown]
# ---
#
# **Q50. 🖊️ Code Writing**
#
# Using the `not` operator, write code to:
# - Check that `x = 7` is **not** greater than 10
# - Check that `name = "Ravi"` is **not** equal to `"Raj"`
#
# Print both results.

# %%
x=7
name = "Ravi"
result1 = not(x>10)
result2= not(name=="raj")
print(result1)
print(result2)
# Out:
# True
# True

# %% [markdown]
# ---
#
# **Q51. 🖊️ Code Writing**
#
# A scholarship is awarded if:
# - Marks > 85 AND attendance >= 90, **OR**
# - The student is from a reserved category (`reserved = True`)
#
# `marks = 80`, `attendance = 95`, `reserved = False`
#
# Write code to check and print the result.

# %%
marks = 80
attendance = 95
reserved = False
scholarship = (marks > 85 and attendance >= 90) or reserved
print(scholarship)
# Out:
# False

# %% [markdown]
# ---
#
# **Q52. 🔍 Predict the Output**
#
# ```python
# a = True
# b = False
# c = True
# print(a and b)
# print(a or b)
# print(not a)
# print(a and b or c)
# print(not (a or b))
# ```

# %%
a = True
b = False
c = True
print(a and b)
print(a or b)
print(not a)
print(a and b or c)
print(not (a or b))
# Out:
# False
# True
# False
# True
# False

# %% [markdown]
# ---
#
# **Q53. 🖊️ Code Writing**
#
# Write code to check if `n = 72` is:
# - Divisible by **both 3 and 4** (use `and`)
# - Divisible by **3 or 4** (use `or`)
#
# Print both results with labels.

# %%
n = 72
both = (n % 3 == 0) and (n % 4 == 0)
either = (n % 3 == 0) or (n % 4 == 0)
print("Divisible by both 3 and 4:", both)
print("Divisible by 3 or 4:", either)
# Out:
# Divisible by both 3 and 4: True
# Divisible by 3 or 4: True

# %% [markdown]
# ---
#
# **Q54. 🖊️ Code Writing**
#
# A voting system allows voting if: age >= 18 AND is_citizen = True AND is_registered = True
#
# `age = 20`, `is_citizen = True`, `is_registered = False`
#
# Write code to check and print whether the person can vote.

# %%
age = 20
is_citizen = True
is_registered = False
can_vote = age>= 18 and is_citizen and is_registered
print(can_vote)
# Out:
# False

# %% [markdown]
# ---
#
# **Q55. 🔍 Predict the Output**
#
# ```python
# x = 5
# print(x > 3 and x < 10)
# print(x > 3 and x > 10)
# print(x < 3 or x < 10)
# print(not x > 3)
# ```

# %%
x = 5
print(x > 3 and x < 10)
print(x > 3 and x > 10)
print(x < 3 or x < 10)
print(not x > 3)
# Out:
# True
# False
# True
# False

# %% [markdown]
# ---
# ---
# ## 📔 Section 4: Membership Operators
# ### *(10 Questions — 8 Code Writing | 2 Predict Output)*

# %% [markdown]
# ---
#
# **Q56. 🖊️ Code Writing**
#
# Create a list: `fruits = ["apple", "banana", "mango", "orange", "grape"]`
#
# Write code to:
# - Check if `"mango"` is in the list
# - Check if `"kiwi"` is NOT in the list
#
# Print both results.

# %%
list = ["apple", "banana", "mango", "orange", "grape"]
print("is 'mango' in the list?:","mango " in list)
print("is 'kiwi' not in the list?:","kiwi" not in list)
# Out:
# is 'mango' in the list?: False
# is 'kiwi' not in the list?: True

# %% [markdown]
# ---
#
# **Q57. 🖊️ Code Writing**
#
# Create a list of allowed users: `["alice", "bob", "charlie", "david"]`
# `current_user = "eve"`
#
# Write code to check if `current_user` is allowed access. Print the result.

# %%
allowed_user = ["alice", "bob", "charlie", "david"]
current_user = "eve"
is_allowed = current_user in allowed_user
print(is_allowed)
# Out:
# False

# %% [markdown]
# ---
#
# **Q58. 🖊️ Code Writing**
#
# `sentence = "Python is a powerful language"`
#
# Write code to check:
# - Is the word `"powerful"` in the sentence?
# - Is the word `"weak"` NOT in the sentence?

# %%
sentence = "Python is a powerful language"
print("Is 'powerful' in the sentence?", "powerful" in sentence)
print("Is 'weak' NOT in the sentence?", "weak" not in sentence)
# Out:
# Is 'powerful' in the sentence? True
# Is 'weak' NOT in the sentence? True

# %% [markdown]
# ---
#
# **Q59. 🔍 Predict the Output**
#
# ```python
# data = [1, "hello", 3.14, True, None]
# print(True in data)
# print(1 in data)
# print(False in data)
# print(None in data)
# ```

# %%
data = [1, "hello", 3.14, True, None]
print(True in data)
print(1 in data)
print(False in data)
print(None in data)
# Out:
# True
# True
# False
# True

# %% [markdown]
# ---
#
# **Q60. 🖊️ Code Writing**
#
# Create a list: `vowels = ["a", "e", "i", "o", "u"]`
#
# Write code to check whether each of the following is a vowel: `"a"`, `"b"`, `"e"`, `"z"`
# Print each result with a label.

# %%
vowels = ["a", "e", "i", "o", "u"]
print("a is a vowel:", "a" in vowels)
print("b is a vowel:", "b" in vowels)
print("e is a vowel:", "e" in vowels)
print("z is a vowel:", "z" in vowels)
# Out:
# a is a vowel: True
# b is a vowel: False
# e is a vowel: True
# z is a vowel: False

# %% [markdown]
# ---
#
# **Q61. 🖊️ Code Writing**
#
# A store has: `["pen", "notebook", "eraser", "stapler", "ruler"]`
#
# A customer asks for `"compass"`.
# Write code to check if the product is available and print the result.

# %%
products = ["pen", "notebook", "eraser", "stapler", "ruler"]
product = "compass"
available = product in products
print(available)
# Out:
# False

# %% [markdown]
# ---
#
# **Q62. 🖊️ Code Writing**
#
# `prime_numbers = (2, 3, 5, 7, 11, 13, 17, 19)`
#
# Check if the following numbers are prime using `in`: `4`, `7`, `15`, `13`
# Print each result.

# %%
prime_numbers = (2, 3, 5, 7, 11, 13, 17, 19)
print("4 is prime:", 4 in prime_numbers)
print("7 is prime:", 7 in prime_numbers)
print("15 is prime:", 15 in prime_numbers)
print("13 is prime:", 13 in prime_numbers)
# Out:
# 4 is prime: False
# 7 is prime: True
# 15 is prime: False
# 13 is prime: True

# %% [markdown]
# ---
#
# **Q63. 🖊️ Code Writing**
#
# Blocked email domains: `["spam.com", "trash.net", "junk.org"]`
# `email = "user@spam.com"`
#
# Use the membership operator to check if `"spam.com"` is in the blocked list.
# Print whether the email should be blocked.

# %%
blocked_email = ["spam.com", "trash.net", "junk.org"]
email = "user@spam.com"
is_blocked = "spam.com" in email
print(is_blocked)
# Out:
# True

# %% [markdown]
# ---
#
# **Q64. 🔍 Predict the Output**
#
# ```python
# nums = [2, 4, 6, 8, 10]
# print(5 in nums)
# print(6 in nums)
# print(3 not in nums)
# print(10 not in nums)
# ```

# %%
nums = [2, 4, 6, 8, 10]
print(5 in nums)
print(6 in nums)
print(3 not in nums)
print(10 not in nums)
# Out:
# False
# True
# True
# False

# %% [markdown]
# ---
#
# **Q65. 🖊️ Code Writing**
#
# `email = "trainer@python.org"`
#
# Using membership operator, check:
# - Does the email contain `"@"`?
# - Does it contain `"gmail"`?
# - Does it NOT contain `"yahoo"`?
#
# Print all three results.

# %%
email = "trainer@python.org"
print("contain '@':","@" in email)
print("contain 'gmail':","gmail " in email)
print("contain not'yahoo':","yahoo" not in email)
# Out:
# contain '@': True
# contain 'gmail': False
# contain not'yahoo': True

# %% [markdown]
# ---
# ---
# ## 📒 Section 5: String Indexing
# ### *(15 Questions — 12 Code Writing | 3 Predict Output)*

# %% [markdown]
# ---
#
# **Q66. 🖊️ Code Writing**
#
# `s = "PYTHON"`
#
# Using **positive indexing**, print:
# - The first character
# - The third character
# - The last character (using positive index)

# %%
s = "PYTHON"
print("First character:", s[0])
print("First character:", s[3])
print("First character:", s[5])
# Out:
# First character: P
# First character: H
# First character: N

# %% [markdown]
# ---
#
# **Q67. 🖊️ Code Writing**
#
# `s = "PYTHON"`
#
# Using **negative indexing**, print:
# - The last character
# - The second-last character
# - The first character (using negative index)

# %%
s = "PYTHON"
print("last character:",s[-1])
print("second_last character:",s[-3])
print("first character:",s[-6])
# Out:
# last character: N
# second_last character: H
# first character: P

# %% [markdown]
# ---
#
# **Q68. 🖊️ Code Writing**
#
# `name = "Sunita Rao"`
#
# Use indexing to print:
# - The first character of the first name
# - The first character of the last name *(last name starts at index 7)*

# %%
name = "Sunita Rao"
print(len(name))
print(name[7: ])
# Out:
# 10
# Rao

# %% [markdown]
# ---
#
# **Q69. 🖊️ Code Writing**
#
# `email = "ravi@gmail.com"`
#
# Use indexing to:
# - Print the character at position `4` (the `@` symbol)
# - Print the last character

# %%
email = "ravi@gmail.com"
print("Character at position 4:", email[4])
print("Last character:", email[-1])
# Out:
# Character at position 4: @
# Last character: m

# %% [markdown]
# ---
#
# **Q70. 🔍 Predict the Output**
#
# ```python
# s = "DataScience"
# print(s[0])
# print(s[4])
# print(s[-1])
# print(s[-7])
# print(len(s))
# ```

# %%
s = "DataScience"
print(s[0])
print(s[4])
print(s[-1])
print(s[-7])
print(len(s))
# Out:
# D
# S
# e
# S
# 11

# %% [markdown]
# ---
#
# **Q71. 🖊️ Code Writing**
#
# `word = "INTERVIEW"`
#
# Write code to:
# - Print the first character
# - Print the middle character *(index 4)*
# - Print the last character using a **negative index**

# %% [raw]
# word = "INTERVIEW"
# print("first character:",word[0])
# print("middle character:",word[4])
# print("Last character:", word[-1])

# %% [markdown]
# ---
#
# **Q72. 🖊️ Code Writing**
#
# `s = "ABCDEFGHIJ"` (10 characters)
#
# Write code to:
# - Print the character at index `0`
# - Print the character at index `9`
# - Verify that `s[0]` and `s[-10]` print the same character

# %%
s = "ABCDEFGHIJ"
print("Character at index 0:", s[0])
print("Character at index 9:", s[9])
print(s[0] == s[-10])
# Out:
# Character at index 0: A
# Character at index 9: J
# True

# %% [markdown]
# ---
#
# **Q73. 🖊️ Code Writing**
#
# `phone = "9876543210"`
#
# Use indexing to:
# - Print the **first digit**
# - Print the **last digit**
# - Print the **5th digit** (index 4)

# %%
phone = "9876543210"
print("first digit:",phone[1])
print("last digit:",phone[9])
print("5th digit :", phone[4])
# Out:
# first digit: 8
# last digit: 0
# 5th digit : 5

# %% [markdown]
# ---
#
# **Q74. 🖊️ Code Writing**
#
# `product_code = "PRD-2024-XZ9"`
#
# Use indexing to:
# - Print the character at index `0`
# - Print the character at index `4`
# - Print the last character using negative indexing

# %%
product_code = "PRD-2024-XZ9"
print("Character at index 0:", product_code[0])
print("Character at index 4:", product_code[4])
print("Last character:", product_code[-1])
# Out:
# Character at index 0: P
# Character at index 4: 2
# Last character: 9

# %% [markdown]
# ---
#
# **Q75. 🖊️ Code Writing**
#
# `s = "Programming"`
#
# Write code to:
# - Find and print the **length** of the string using `len()`
# - Print the character at the **last valid positive index**

# %%
s = "Programming"
print(len(s))
print(s[len(s) - 1])
# Out:
# 11
# g

# %% [markdown]
# ---
#
# **Q76. 🔍 Predict the Output**
#
# ```python
# s = "Hello World"
# print(s[0])
# print(s[6])
# print(s[-1])
# print(s[-5])
# print(s[len(s)-1])
# ```

# %%
s = "Hello World"
print(s[0])
print(s[6])
print(s[-1])
print(s[-5])
print(s[len(s)-1])
# Out:
# H
# W
# d
# W
# d

# %% [markdown]
# ---
#
# **Q77. 🖊️ Code Writing**
#
# `roll = "2024CSIT0087"`
#
# Use indexing to:
# - Print the first character of the year *(index 0)*
# - Print the first character of the branch code *(index 4)*
# - Print the last character *(negative index)*

# %%
roll = "2024CSIT0087"
print("Year first character:", roll[0])
print("Branch first character:", roll[4])
print("Last character:", roll[-1])
# Out:
# Year first character: 2
# Branch first character: C
# Last character: 7

# %% [markdown]
# ---
#
# **Q78. 🖊️ Code Writing**
#
# `s = "Python"`
#
# Using `len()` and indexing, print:
# - The **middle-left character** *(index: length // 2 - 1)*
# - The **middle-right character** *(index: length // 2)*

# %%
s = "Python"
length = len(s)
print("Middle-left character:", s[length // 2 - 1])
print("Middle-right character:", s[length // 2])
# Out:
# Middle-left character: t
# Middle-right character: h

# %% [markdown]
# ---
#
# **Q79. 🖊️ Code Writing**
#
# `barcode = "8901030408947"`
#
# Use indexing to:
# - Print the first character
# - Print the character at index `6`
# - Print the last character using a negative index

# %%
barcode = "8901030408947"
print("First character:", barcode[0])
print("Character at index 6:", barcode[6])
print("Last character:", barcode[-1])
# Out:
# First character: 8
# Character at index 6: 0
# Last character: 7

# %% [markdown]
# ---
#
# **Q80. 🔍 Predict the Output**
#
# ```python
# s = "PYTHON"
# print(s[0] == s[-6])
# print(s[5] == s[-1])
# print(s[2] == s[-4])
# ```

# %%
s = "PYTHON"
print(s[0] == s[-6])
print(s[5] == s[-1])
print(s[2] == s[-4])
# Out:
# True
# True
# True

# %% [markdown]
# ---
# ---
# ## 📕 Section 6: String Slicing
# ### *(20 Questions — 17 Code Writing | 3 Predict Output)*

# %% [markdown]
# ---
#
# **Q81. 🖊️ Code Writing**
#
# `s = "PYTHON"`
#
# Slice and print:
# - The first 3 characters
# - The last 3 characters
# - Characters from index 2 to 5

# %%
s = "PYTHON"
print(s[:3])
print(s[-3:])
print(s[2:6])
# Out:
# PYT
# HON
# THON

# %% [markdown]
# ---
#
# **Q82. 🖊️ Code Writing**
#
# `s = "PROGRAMMING"`
#
# Use and print:
# - `s[:4]`
# - `s[7:]`
# - `s[:]`
#
# Add a comment for each explaining what it does.

# %%
s = "PROGRAMMING"
print(s[:4])   
print(s[7:])   
print(s[:])
# Out:
# PROG
# MING
# PROGRAMMING

# %% [markdown]
# ---
#
# **Q83. 🖊️ Code Writing**
#
# `s = "ABCDEFGHIJ"`
#
# Extract:
# - Characters at every 2nd position starting from index 0 → `[::2]`
# - Characters at every 2nd position starting from index 1 → `[1::2]`
# - Characters at every 3rd position → `[::3]`

# %%
s = "ABCDEFGHIJ"
print(s[::2])  
print(s[1::2])  
print(s[::3])

# %% [markdown]
# ---
#
# **Q84. 🖊️ Code Writing**
#
# `s = "PYTHON"`
#
# Write slicing expressions to:
# - Reverse the entire string
# - Reverse only the first 4 characters

# %%
s = "PYTHON"
print(s[::-1])
print(s[:4][::-1])
# Out:
# NOHTYP
# HTYP

# %% [markdown]
# ---
#
# **Q85. 🖊️ Code Writing**
#
# `s = "ABCDEFGHIJ"`
#
# Print:
# - The last 4 characters using **negative slicing** `[-4:]`
# - All except the last 3 characters `[:-3]`
# - Characters from index -6 to -2

# %%
s = "ABCDEFGHIJ"
print(s[-4:])
print(s[:-3])
print(s[-6:-2])
# Out:
# GHIJ
# ABCDEFG
# EFGH

# %% [markdown]
# ---
#
# **Q86. 🔍 Predict the Output**
#
# ```python
# s = "DataScience"
# print(s[0:4])
# print(s[4:])
# print(s[:4])
# print(s[-7:-3])
# print(s[::2])
# ```

# %%
s = "DataScience"
print(s[0:4])
print(s[4:])
print(s[:4])
print(s[-7:-3])
print(s[::2])
# Out:
# Data
# Science
# Data
# Scie
# DtSine

# %% [markdown]
# ---
#
# **Q87. 🖊️ Code Writing**
#
# `s = "Hello, World!"`
#
# Use slicing to extract:
# - `"Hello"`
# - `"World"`
# - `"World!"`

# %%
s = "Hello, World!"
print(s[:5])      
print(s[7:12])    
print(s[7:])
# Out:
# Hello
# World
# World!

# %% [markdown]
# ---
#
# **Q88. 🖊️ Code Writing**
#
# `s = "PYTHON"`
#
# Write a slicing expression that returns an **empty string**.
# Add a comment explaining why it returns empty.

# %%
s = "PYTHON"
print(s[4:2])

# %% [markdown]
# ---
#
# **Q89. 🖊️ Code Writing**
#
# `s = "0123456789"`
#
# Extract:
# - All **even-position digits** using `[::2]`
# - All **odd-position digits** using `[1::2]`

# %%
s = "0123456789"
print(s[::2])    
print(s[1::2])
# Out:
# 02468
# 13579

# %% [markdown]
# ---
#
# **Q90. 🖊️ Code Writing**
#
# `date = "25-12-2024"`
#
# Use slicing to extract:
# - Day: `"25"`
# - Month: `"12"`
# - Year: `"2024"`
#
# Print each with a label.

# %%
date = "25-12-2024"
day = date[:2]
month = date[3:5]
year = date[6:]
print("Day:", day)
print("Month:", month)
print("Year:", year)
# Out:
# Day: 25
# Month: 12
# Year: 2024

# %% [markdown]
# ---
#
# **Q91. 🖊️ Code Writing**
#
# `email = "trainer@python.org"`
#
# Use slicing to extract:
# - The **username** (everything before `@`)
# - The **domain** (everything after `@`)
#
# *(Count characters to find the correct index)*

# %%
email = "trainer@python.org"
username = email[:7]
domain = email[8:]
print("Username:", username)
print("Domain:", domain)
# Out:
# Username: trainer
# Domain: python.org

# %% [markdown]
# ---
#
# **Q92. 🖊️ Code Writing**
#
# `s = "MADAM"`
#
# - Reverse the string using slicing
# - Check if the string equals its reverse
# - Print whether it is a palindrome

# %%
s = "MADAM"
reverse = s[::-1]
print("Reversed:", reverse)
print("Is Palindrome:", s == reverse)
# Out:
# Reversed: MADAM
# Is Palindrome: True

# %% [markdown]
# ---
#
# **Q93. 🖊️ Code Writing**
#
# `filename = "report_2024.xlsx"`
#
# Use slicing to:
# - Extract the file extension `"xlsx"` using **negative slicing**
# - Extract the filename without extension `"report_2024"`

# %%
emp_id = "EMP-HR-2024-001"
company = emp_id[:3]
department = emp_id[4:6]
year = emp_id[7:11]
employee_number = emp_id[-3:]
print("Company:", company)
print("Department:", department)
print("Year:", year)
print("Employee Number:", employee_number)
# Out:
# Company: EMP
# Department: HR
# Year: 2024
# Employee Number: 001

# %% [markdown]
# ---
#
# **Q94. 🖊️ Code Writing**
#
# `emp_id = "EMP-HR-2024-001"`
#
# Use slicing to extract:
# - `"EMP"` (first 3 characters)
# - `"HR"` (department code)
# - `"2024"` (year)
# - `"001"` (employee number)

# %%
emp_id = "EMP-HR-2024-001"
company = emp_id[:3]
department = emp_id[4:6]
year = emp_id[7:11]
employee_number = emp_id[-3:]
print("Company:", company)
print("Department:", department)
print("Year:", year)
print("Employee Number:", employee_number)
# Out:
# Company: EMP
# Department: HR
# Year: 2024
# Employee Number: 001

# %% [markdown]
# ---
#
# **Q95. 🖊️ Code Writing**
#
# `s = "ABCDEFGHIJ"`
#
# Write slicing expressions for:
# - Characters from index 2 to 8 with **step 2**
# - Characters from index 7 to 2 in **reverse** (step -1)
# - Characters from index 9 to 0 with **step -3**

# %%
s = "ABCDEFGHIJ"
print(s[2:9:2])
print(s[7:2:-1])
print(s[9::-3])
# Out:
# CEGI
# HGFED
# JGDA

# %% [markdown]
# ---
#
# **Q96. 🖊️ Code Writing**
#
# `card = "1234567890123456"` (16-digit card number)
#
# Use slicing to:
# - Extract and print the **last 4 digits** (visible part)
# - Extract the **first 12 digits** (masked part)

# %%
card = "1234567890123456"
visible = card[-4:]
masked = card[:12]
print("Visible Part:", visible)
print("Masked Part:", masked)
# Out:
# Visible Part: 3456
# Masked Part: 123456789012

# %% [markdown]
# ---
#
# **Q97. 🔍 Predict the Output**
#
# ```python
# s = "PYTHON"
# print(s[4:1:-1])
# print(s[::-2])
# print(s[-1:-4:-1])
# print(s[10:20])
# ```

# %%
s = "PYTHON"
print(s[4:1:-1])
print(s[::-2])
print(s[-1:-4:-1])
print(s[10:20])
# Out:
# OHT
# NHY
# NOH

# %% [markdown]
# ---
#
# **Q98. 🖊️ Code Writing**
#
# `s = "H_e_l_l_o"`
#
# Use step slicing `[::2]` to extract only the letters.
# Print the result.

# %%
s = "H_e_l_l_o"
print(s[::2])
# Out:
# Hello

# %% [markdown]
# ---
#
# **Q99. 🖊️ Code Writing**
#
# `s = "NOHTYP"`
#
# Use **reverse slicing** to convert it into `"PYTHON"`.
# Print the result.

# %%
s = "NOHTYP"
print(s[::-1])
# Out:
# PYTHON

# %% [markdown]
# ---
#
# **Q100. 🖊️ Code Writing**
#
# `roll = "2024CSIT0087"`
#
# Use slicing to extract:
# - Admission Year: `"2024"` (index 0 to 4)
# - Branch: `"CSIT"` (index 4 to 8)
# - Student Number: `"0087"` (last 4 characters)
#
# Print each with a label.

# %%
roll = "2024CSIT0087"
admission_year = roll[:4]
branch = roll[4:8]
student_number = roll[-4:]
print("Admission Year:", admission_year)
print("Branch:", branch)
print("Student Number:", student_number)
# Out:
# Admission Year: 2024
# Branch: CSIT
# Student Number: 0087

# %% [markdown]
# ---
# ---
# ## 🌍 Section 7: Scenario-Based Challenges
# ### *(10 Questions — 10 Code Writing)*

# %% [markdown]
# ---
#
# **Q101. 🖊️ Code Writing — OTP Extraction**
#
# `msg = "Your OTP is 847392. Do not share."`
#
# The OTP is always at positions 12 to 18.
# Use slicing to extract and print the OTP.

# %%
msg = "Your OTP is 847392. Do not share."
otp = msg[12:18]
print(otp)
# Out:
# 847392

# %% [markdown]
# ---
#
# **Q102. 🖊️ Code Writing — Hashtag Removal**
#
# `tag = "#MachineLearning"`
#
# Use slicing to remove the `#` and print only `"MachineLearning"`.

# %%
tag = "#MachineLearning"
print(tag[1:])
# Out:
# MachineLearning

# %% [markdown]
# ---
#
# **Q103. 🖊️ Code Writing — Reverse to Find Original**
#
# A prankster reversed a friend's name:
# `reversed_name = "avahB"`
#
# Use slicing to recover and print the original name.

# %%
reversed_name = "avahB"
print(reversed_name[::-1])

# %% [markdown]
# ---
#
# **Q104. 🖊️ Code Writing — Barcode Country Code**
#
# `barcode = "8901030408947"`
#
# The first 3 digits are the country code (`890` = India).
# Use slicing to extract and print the country code.

# %%
barcode = "8901030408947"
country_code = barcode[:3]
print(country_code)
# Out:
# 890

# %% [markdown]
# ---
#
# **Q105. 🖊️ Code Writing — Alternate Characters Pattern**
#
# `s = "AaBbCcDdEe"`
#
# Use step slicing to extract:
# - Only **uppercase** letters → `[::2]`
# - Only **lowercase** letters → `[1::2]`

# %%
s = "AaBbCcDdEe"
print(s[::2])
print(s[1::2])
# Out:
# ABCDE
# abcde

# %% [markdown]
# ---
#
# **Q106. 🖊️ Code Writing — Mirror String**
#
# `s = "PYTHON"`
#
# Using **concatenation and slicing**, create and print the mirror string: `"PYTHONNOHTYP"`

# %%
s = "PYTHON"
mirror = s + s[::-1]
print(mirror)
# Out:
# PYTHONNOHTYP

# %% [markdown]
# ---
#
# **Q107. 🖊️ Code Writing — URL Cleanup**
#
# `url = "https://www.openai.com"`
#
# Use slicing to extract only `"openai"` from the URL.
# *(Hint: `https://www.` is 12 characters; `.com` is the last 4)*

# %%
url = "https://www.openai.com"
website = url[12:-4]
print(website)
# Out:
# openai

# %% [markdown]
# ---
#
# **Q108. 🖊️ Code Writing — Phone Number Formatting**
#
# `phone = "09876543210"`
#
# Use slicing to:
# - Remove the leading `0` and print the remaining 10 digits
# - Print the last 4 digits as a short caller ID

# %%
phone = "09876543210"
print(phone[1:])
print(phone[-4:])
# Out:
# 9876543210
# 3210

# %% [markdown]
# ---
#
# **Q109. 🖊️ Code Writing — Word Reversal Check**
#
# `word1 = "LISTEN"`
# `word2 = "NETSIL"`
#
# Use slicing to reverse `word1` and check if it equals `word2`.
# Print the boolean result.

# %%
word1 = "LISTEN"
word2 = "NETSIL"
print(word1[::-1] == word2)
# Out:
# True

# %% [markdown]
# ---
#
# **Q110. 🖊️ Code Writing — Secret Code Decoder**
#
# A secret message was encoded by reversing the text:
# `encoded = "!dlroW ,olleH"`
#
# Use slicing to decode and print the original message.

# %%
encoded = "!dlroW ,olleH"
decoded = encoded[::-1]
print(decoded)
# Out:
# Hello, World!
